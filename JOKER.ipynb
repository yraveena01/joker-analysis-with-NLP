# %% [markdown]
# ![joker%20logo.png](attachment:joker%20logo.png)

# %% [markdown]
# The rise of Arthur Fleck, from aspiring stand-up comedian and pariah to Gotham's clown prince and leader of the revolution
#
# The movie joker is about a common man who is forced by society to become the supervillain known as joker.
#
# His mom abused him, friends betrayed him, and society abandoned him. He is result of his circumstances. The actions of the joker mirror that of a animal which is cornered. The film is in a line, Revenge of a common man on the society.

# %%
#importing import libraries
import nltk 

from nltk import sent_tokenize
from nltk import word_tokenize

# %% [markdown]
# ### READING JOKER FILE

# %%
text_file = open('/Users/admin/Desktop/joker_script.txt')

# %% [markdown]
# ![joker2.jpg](attachment:joker2.jpg)

# %%
text = text_file.read()

# %%
print(text)
print("\n")
# Out:
# JOKER
#
#                           AN ORIGIN
#
#
#
#
#                          Written by
#
#                  Todd Phillips & Scott Silver
#
#
#
#
#                                                   13 April 2018
#
#   This story takes place in its own universe. It has no
#   connection to any of the DC films that have come before it.
#
#   We see it as a classic Warner Bros. movie. Gritty, intimate
#   and oddly funny, the characters live in the real world and
#   the stakes are personal.
#
#   Although it is never mentioned in the film, this story takes
#   place in the past.
#
#   Let's call it 1981.
#
#   It's a troubled time. The crime rate in Gotham is at record
#   highs. A garbage strike has crippled the city for the past
#   six weeks. And the divide between the "haves" and the "have-
#   nots" is palpable. Dreams are beyond reach, slipping into
#   delusions.
#
#
#
#                                                       OVER BLACK:
#
#     HEAR LAUGHTER.
#
# ...

# %%
print(len(text))
# Out:
# 226300

# %% [markdown]
# ## KEYWORD ANALYSIS

# %% [markdown]
# Keyword analysis in NLP refers to the process of identifying and extracting the most relevant and important words or phrases from a given text or set of texts. These words or phrases are typically used to describe the central themes, topics, or ideas that are present in the text.

# %% [markdown]
# #### TOKENIZATION

# %% [markdown]
# Tokenization is an important step in many natural language processing tasks because it allows computers to analyze and understand human language. By breaking a text into individual tokens, a computer can count the frequency of words, identify grammatical patterns, and perform other language-related analyses.

# %%
#sentence tokenization 

sentences=sent_tokenize(text)

# %%
print(len(sentences))
sentences
# Out:
# 2784
# ['JOKER\n\n                          AN ORIGIN\n\n\n\n\n                         Written by\n\n                 Todd Phillips & Scott Silver\n\n\n\n\n                                                  13 April 2018 \n\n  This story takes place in its own universe.',
#  'It has no\n  connection to any of the DC films that have come before it.',
#  'We see it as a classic Warner Bros. movie.',
#  'Gritty, intimate\n  and oddly funny, the characters live in the real world and\n  the stakes are personal.',
#  'Although it is never mentioned in the film, this story takes\n  place in the past.',
#  "Let's call it 1981.",
#  "It's a troubled time.",
#  'The crime rate in Gotham is at record\n  highs.',
#  'A garbage strike has crippled the city for the past\n  six weeks.',
#  'And the divide between the "haves" and the "have-\n  nots" is palpable.',
#  'Dreams are beyond reach, slipping into\n  delusions.',
#  'OVER BLACK:\n\n    HEAR LAUGHTER.',
# ...

# %%
#word tokenization

word = word_tokenize (text)

# %%
word
# Out:
# ['JOKER',
#  'AN',
#  'ORIGIN',
#  'Written',
#  'by',
#  'Todd',
#  'Phillips',
#  '&',
#  'Scott',
#  'Silver',
#  '13',
#  'April',
#  '2018',
#  'This',
#  'story',
#  'takes',
#  'place',
#  'in',
#  'its',
#  'own',
#  'universe',
#  '.',
#  'It',
#  'has',
#  'no',
#  'connection',
#  'to',
#  'any',
#  'of',
#  'the',
#  'DC',
#  'films',
#  'that',
#  'have',
#  'come',
#  'before',
#  'it',
#  '.',
#  'We',
#  'see',
#  'it',
#  'as',
#  'a',
#  'classic',
#  'Warner',
#  'Bros.',
#  'movie',
#  '.',
#  'Gritty',
#  ',',
#  'intimate',
#  'and',
#  'oddly',
#  'funny',
#  ',',
#  'the',
#  'characters',
#  'live',
#  'in',
#  'the',
#  'real',
#  'world',
#  'and',
#  'the',
#  'stakes',
#  'are',
#  'personal',
#  '.',
#  'Although',
#  'it',
#  'is',
#  'never',
#  'mentioned',
#  'in',
#  'the',
#  'film',
#  ',',
#  'this',
#  'story',
#  'takes',
#  'place',
#  'in',
#  'the',
#  'past',
#  '.',
#  'Let',
#  "'s",
#  'call',
#  'it',
#  '1981',
#  '.',
#  'It',
# ...

# %%
#the length of the text file 
print(len(word))
# Out:
# 33273

# %%
#frequency distribution of the joker script 

import tokenize 
from nltk.probability import FreqDist

# %%
#plotting frequency distribution graph 

fdist=FreqDist(word)
fdist.most_common(20)
fdist.plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### REMOVING PUNCTUATIONS

# %% [markdown]
# Removing punctuation is a common pre-processing step in natural language processing and text analysis. It involves removing any punctuation marks (such as periods, commas, question marks, etc.) from a text or document, leaving only the words and numbers.

# %%
word_no_punctuation= []

for w in word:
    if w.isalpha():
       word_no_punctuation.append(w.lower())

# %%
print(word_no_punctuation)
# Out:
# ['joker', 'an', 'origin', 'written', 'by', 'todd', 'phillips', 'scott', 'silver', 'april', 'this', 'story', 'takes', 'place', 'in', 'its', 'own', 'universe', 'it', 'has', 'no', 'connection', 'to', 'any', 'of', 'the', 'dc', 'films', 'that', 'have', 'come', 'before', 'it', 'we', 'see', 'it', 'as', 'a', 'classic', 'warner', 'movie', 'gritty', 'intimate', 'and', 'oddly', 'funny', 'the', 'characters', 'live', 'in', 'the', 'real', 'world', 'and', 'the', 'stakes', 'are', 'personal', 'although', 'it', 'is', 'never', 'mentioned', 'in', 'the', 'film', 'this', 'story', 'takes', 'place', 'in', 'the', 'past', 'let', 'call', 'it', 'it', 'a', 'troubled', 'time', 'the', 'crime', 'rate', 'in', 'gotham', 'is', 'at', 'record', 'highs', 'a', 'garbage', 'strike', 'has', 'crippled', 'the', 'city', 'for', 'the', 'past', 'six', 'weeks', 'and', 'the', 'divide', 'between', 'the', 'haves', 'and', 'the', 'nots', 'is', 'palpable', 'dreams', 'are', 'beyond', 'reach', 'slipping', 'into', 'delusions', 'over', 'blac
# ...

# %%
print
(len(word_no_punctuation))
# Out:
# 25751

# %%
fdist=FreqDist(word_no_punctuation)
fdist.most_common(15)
fdist.plot(15)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### REMOVING STOPWORDS

# %% [markdown]
# Removing stopwords is another common pre-processing step in natural language processing and text analysis. Stopwords are words that are commonly used in a language, but do not carry much meaning on their own, such as "the", "a", "an", "and", "in", "of", etc. Removing these words can help to improve the accuracy and efficiency of text analysis by reducing noise and simplifying the data.

# %%
from nltk.corpus import stopwords

# %%
stopwords = stopwords.words('english')
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
clean_words=[]

# %%
for w in word_no_punctuation:
    if w not in stopwords:
        clean_words.append(w)

# %%
#script after removing punctuation and stopwords 

print(clean_words)
# Out:
# ['joker', 'origin', 'written', 'todd', 'phillips', 'scott', 'silver', 'april', 'story', 'takes', 'place', 'universe', 'connection', 'dc', 'films', 'come', 'see', 'classic', 'warner', 'movie', 'gritty', 'intimate', 'oddly', 'funny', 'characters', 'live', 'real', 'world', 'stakes', 'personal', 'although', 'never', 'mentioned', 'film', 'story', 'takes', 'place', 'past', 'let', 'call', 'troubled', 'time', 'crime', 'rate', 'gotham', 'record', 'highs', 'garbage', 'strike', 'crippled', 'city', 'past', 'six', 'weeks', 'divide', 'haves', 'nots', 'palpable', 'dreams', 'beyond', 'reach', 'slipping', 'delusions', 'black', 'hear', 'laughter', 'sound', 'man', 'totally', 'cracking', 'fade', 'int', 'dept', 'health', 'office', 'morning', 'close', 'joker', 'tears', 'eyes', 'laughing', 'hard', 'trying', 'get', 'control', 'greasy', 'black', 'hair', 'matted', 'wearing', 'old', 'faded', 'red', 'hooded', 'sweatshirt', 'threadbare', 'gray', 'scarf', 'thin', 'years', 'use', 'hangs', 'loosely', 'around', 'nec
# ...

# %%
print(len(clean_words))
# Out:
# 14265

# %%
#the most common words in the text file 
fdist=FreqDist(clean_words)
fdist.most_common(20)
# Out:
# [('joker', 779),
#  ('back', 133),
#  ('murray', 131),
#  ('sophie', 105),
#  ('looks', 100),
#  ('like', 94),
#  ('int', 90),
#  ('mom', 90),
#  ('wayne', 87),
#  ('face', 84),
#  ('street', 80),
#  ('franklin', 69),
#  ('one', 68),
#  ('randall', 68),
#  ('see', 67),
#  ('know', 66),
#  ('beat', 65),
#  ('wall', 63),
#  ('mother', 62),
#  ('behind', 61)]

# %%
#ploting the frequency graph 
fdist.plot(10)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ![qw.jpg](attachment:qw.jpg)

# %% [markdown]
# # Word Cloud

# %% [markdown]
# Word cloud is a popular visualization technique that can be used in natural language processing (NLP) to represent text data visually. A word cloud is a graphical representation of the most frequent words or terms in a corpus, where the size of each word or term represents its frequency in the text.

# %%
#importing libraries for wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud= WordCloud(width= 1000,height =1000, background_color= 'black', colormap='Blues').generate(text)

# %%
plt.figure(figsize=(3,3))
plt.imshow(wordcloud)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# WORDCLOUD ON THE BASIS OF SENTIMENTS

# %% [markdown]
# Sentiment analysis: Word cloud can be used to visualize the most common positive and negative words in a text, providing a quick summary of the overall sentiment of the text.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sentiment_analyzer= SentimentIntensityAnalyzer()
sentiments=[(word,sentiment_analyzer.polarity_scores(word)['compound'])for word in word]

# %%
sentiments
# Out:
# [('JOKER', 0.128),
#  ('AN', 0.0),
#  ('ORIGIN', 0.0),
#  ('Written', 0.0),
#  ('by', 0.0),
#  ('Todd', 0.0),
#  ('Phillips', 0.0),
#  ('&', 0.0),
#  ('Scott', 0.0),
#  ('Silver', 0.0),
#  ('13', 0.0),
#  ('April', 0.0),
#  ('2018', 0.0),
#  ('This', 0.0),
#  ('story', 0.0),
#  ('takes', 0.0),
#  ('place', 0.0),
#  ('in', 0.0),
#  ('its', 0.0),
#  ('own', 0.0),
#  ('universe', 0.0),
#  ('.', 0.0),
#  ('It', 0.0),
#  ('has', 0.0),
#  ('no', -0.296),
#  ('connection', 0.0),
#  ('to', 0.0),
#  ('any', 0.0),
#  ('of', 0.0),
#  ('the', 0.0),
#  ('DC', 0.0),
#  ('films', 0.0),
#  ('that', 0.0),
#  ('have', 0.0),
#  ('come', 0.0),
#  ('before', 0.0),
#  ('it', 0.0),
#  ('.', 0.0),
#  ('We', 0.0),
#  ('see', 0.0),
#  ('it', 0.0),
#  ('as', 0.0),
#  ('a', 0.0),
#  ('classic', 0.0),
#  ('Warner', 0.0),
#  ('Bros.', 0.0),
#  ('movie', 0.0),
#  ('.', 0.0),
#  ('Gritty', 0.0),
#  (',', 0.0),
#  ('intimate', 0.0),
#  ('and', 0.0),
#  ('oddly', 0.0),
#  ('funny', 0.4404),
#  (',', 0.0),
# ...

# %%
positive_words = [word for word, sentiment in sentiments if sentiment > 0]

# %%
stop_words = (clean_words)

# %%
positive_wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(" ".join(positive_words))


positive_wordcloud

# %%
plt.figure(figsize=(3,3))
plt.imshow(positive_wordcloud)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
negative_words = [word for word , sentiment in sentiments if sentiment <0]

# %%
negative_wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(" ".join(negative_words))


negative_wordcloud

# %%
plt.figure(figsize=(3,3))
plt.imshow(negative_wordcloud)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from PIL import Image 
import numpy as np

# %%
im = np.array(Image.open("/Users/admin/Desktop/HJ.png"))

# %%
wordcloud = WordCloud(mask = im).generate(text)
plt.figure(figsize = (15, 15))
background_color ='white'
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# ### SENTIMENT ANALYSIS

# %%
from textblob import TextBlob

# %%
text1= "She has good days. But mostly bad."

# %%
textblob= TextBlob(text1)

# %%
sentiment = textblob.sentiment.polarity

# %%
if sentiment > 0 :
    print("This text is positive")

else :
    print ("This text is negative")
# Out:
# This text is positive

# %%
text2 = "joker died ."
textblob = TextBlob(text2)
sentiment= textblob.sentiment.polarity

if sentiment > 0 :
    print("This text is positive")

else :
    print ("This text is negative")
# Out:
# This text is negative

# %% [markdown]
# ## TEXT CLUSTERING

# %%
#importing libraries for text clustering through k-means 
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.cluster import KMeans

# %%
documents= ["This story takes place in its own universe. It has no connection to any of the DC films that have come before it.",

  "We see it as a classic Warner Bros. movie. Gritty, intimate and oddly funny, the characters live in the real world and the stakes are personal.",

  "Although it is never mentioned in the film, this story takes place in the past.",

  "Let's call it 1981.",

  "It's a troubled time. The crime rate in Gotham is at record highs. A garbage strike has crippled the city for the past six weeks. And the divide between the  haves and the  have- nots is palpable. Dreams are beyond reach, slipping into delusions. "]

# %%
vectorizer = TfidfVectorizer(stop_words = 'english')
X = vectorizer.fit_transform(documents)

# %%
terms = vectorizer.get_feature_names()
from sklearn.metrics.pairwise import cosine_similarity
dist = 1- cosine_similarity(X)
# Out:
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
model = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 100, n_init = 1)
model.fit(X)
# Out:
# KMeans(max_iter=100, n_clusters=2, n_init=1)

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(2):
    print("Cluster Number:", i), 
    for c in order_centroids[i, :10]: 
        print('%s' % terms[c])
# Out:
# Cluster Number: 0
# 1981
# let
# real
# bros
# characters
# classic
# funny
# gritty
# intimate
# movie
# Cluster Number: 1
# story
# place
# takes
# past
# film
# mentioned
# connection
# dc
# films
# universe
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
from scipy.cluster.hierarchy import ward, dendrogram
import matplotlib.pyplot as plt
import numpy as np

# create a random dataset
X = np.random.rand(10, 2)

# compute the distance matrix using the Euclidean distance
dist = np.sqrt(((X[:, None, :] - X[None, :, :])**2).sum(-1))

# plot the dendrogram
linkage_matrix = ward(dist)
fig, ax = plt.subplots(figsize=(8, 8))
ax = dendrogram(linkage_matrix, orientation="right")
plt.show()
# Out:
# /Users/admin/opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py:834: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %% [markdown]
# The dendrogram shows the hierarchical clustering tree of the input dataset, where each leaf node represents a single sample and each internal node represents a cluster of samples. The height of each node corresponds to the distance or dissimilarity between the clusters or samples that it connects.

# %% [markdown]
# ### TRANSLATION

# %%
from translate import Translator

# %%
# JAPANESE 
translator = Translator(to_lang="ja")
translation = translator.translate("I used to think that my life was a tragedy, but now I realize, it’s a comedy ")
print(translation)
# Out:
# 私は自分の人生は悲劇だと思っていましたが、今ではそれが喜劇だと気づきました。

# %%
# TURKISH 
translator = Translator(to_lang="tr")
translation = translator.translate("My mother always tells me to smile and put on a happy face. She told me I had a purpose: to bring laughter and joy to the world")
print(translation)
# Out:
# Annem her zaman gülümsememi ve mutlu bir yüz takınmamı söyler. Bana bir amacım olduğunu söyledi: dünyaya kahkaha ve neşe getirmek.

# %%
# GERMAN 
translator = Translator(to_lang="de")
translation = translator.translate(" All I have are negative thoughts")
print(translation)
# Out:
# Ich habe nur negative Gedanken.

# %% [markdown]
# ![jokerrrrr.jpg](attachment:jokerrrrr.jpg)

# %% [markdown]
# ### TEXT SUMMARIZATION

# %%
from nltk import sent_tokenize, PorterStemmer, word_tokenize

# %%
#creating frequency matrix for tokens

def create_frequency_matrix(sentences):
    frequency_matrix = {}
    stop_words = set(stopwords.word('english'))
    ps = PorterStemmer()
    
    for sent in sentences: 
        freq_table = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            word = ps.stem(word)
            if word in stop_words:
                continue
            if word in freq_table:
                freq_table[word] = freq_table[word] + 1
            else:
                freq_table[word] = 1
        frequency_matrix[sent[:15]] = freq_table
        
    return frequency_matrix

# %%
# Manual Term-Frequency Computation

def create_tf_matrix(freq_matrix):
    tf_matrix = {}
    for sent, f_table in freq_matrix.items():
        tf_table = {}
        count_words_in_sent = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sent
        tf_matrix[sent] = tf_table
    return tf_matrix

# %%
#creating doucuments per words

def create_document_per_words(freq_matrix):
    word_per_doc_table = {}
    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] = word_per_doc_table[word] + 1
            else:
                word_per_doc_table[word] = 1
    return word_per_doc_table

# %%
# Manual IDF Computation

import math
def create_idf_matrix(freq_matrix, count_doc_per_words, total_documents):
    idf_matrix = {}
    for sent, f_table in freq_matrix.items():
        idf_table = {}
        for word in f_table.keys():
            idf_table[word] = math.log10(total_documents / float(count_doc_per_words[word]))
        idf_matrix[sent] = idf_table
        return idf_matrix

# %%
#TF-IDF Computation

def create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}
    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):
        tf_idf_table = {}
        for (word1, value1), (word2, value2) in zip(f_table1.items(), f_table2.items()):
            tf_idf_table[word1] = float(value1 * value2)
        tf_idf_matrix[sent1] = tf_idf_table
    return tf_idf_matrix

# %%
# Weighing the words in a sentence - Scoring

def score_sentences(tf_idf_matrix) -> dict: 
    sentence_val = {}
    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0
        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence = total_score_per_sentence + score
        if count_words_in_sentence > 0:
            sentence_val[sent] = total_score_per_sentence / count_words_in_sentence
    return sentence_val

# %%
#Average sentence score - Threshold

def find_average_score(sentence_val) -> int:
    sum_values = 0
    for entry in sentence_val:
        sum_values = sum_values + sentence_val[entry]
    average = sum_values / len(sentence_val)
    return average

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

def create_frequency_matrix(sentences):
    frequency_matrix = {}
    stop_words = set(stopwords.words('english'))
    ps = PorterStemmer()

    for sent in sentences:
        freq_table = {}
        words = word_tokenize(sent)
        for word in words:
            word = ps.stem(word)
            if word in stop_words:
                continue
            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:15]] = freq_table

    return frequency_matrix

# %%
#generating summary 

def generate_summary(sentences, sentence_val, threshold):
    sentence_count = 0
    summary = ""
    for sentence in sentences:
        if sentence[:15] in sentence_val and sentence_val[sentence[:15]] >= (threshold):
            summary = summary + " " + sentence
            sentence_count = sentence_count + 1
    return summary

# %% [markdown]
# CALL EVERYTHING AND GET THE SUMMARIZATION DONE

# %%
freq_matrix= create_frequency_matrix(sentences)

# %%
tf_matrix = create_tf_matrix(freq_matrix)

# %%
count_doc_per_words= create_document_per_words(freq_matrix)

# %%
total_documents = len(sentences)
idf_matrix = create_idf_matrix(freq_matrix, count_doc_per_words, total_documents)

# %%
idf_matrix= create_idf_matrix(freq_matrix,count_doc_per_words,total_documents)

# %%
tf_idf_matrix= create_tf_idf_matrix(tf_matrix,idf_matrix)

# %%
sentence_score= score_sentences(tf_idf_matrix)

# %%
threshold = find_average_score(sentence_score)

# %%
#summary of joker script 

summary= generate_summary(sentences, sentence_score, threshold)
summary
# Out:
# ' JOKER\n\n                          AN ORIGIN\n\n\n\n\n                         Written by\n\n                 Todd Phillips & Scott Silver\n\n\n\n\n                                                  13 April 2018 \n\n  This story takes place in its own universe.'

# %% [markdown]
# ![TY.jpg](attachment:TY.jpg)

# %% [markdown]
# ![jokerrrrr.jpg](attachment:jokerrrrr.jpg)
